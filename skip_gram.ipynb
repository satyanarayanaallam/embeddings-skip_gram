# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# 1. Prepare corpus
corpus = "the cat sat on the mat".split()
vocab = list(set(corpus))
word_to_ix = {word: i for i, word in enumerate(vocab)}

# %%
# 2. Generate skip-gram pairs
def make_pairs(corpus, window_size=2):
    pairs = []
    for idx, word in enumerate(corpus):
        for j in range(max(0, idx-window_size), min(len(corpus), idx+window_size+1)):
            if j != idx:
                pairs.append((word, corpus[j]))
    return pairs

# %%
pairs = make_pairs(corpus)

# %%
pairs
# Out:
# [('the', 'cat'),
#  ('the', 'sat'),
#  ('cat', 'the'),
#  ('cat', 'sat'),
#  ('cat', 'on'),
#  ('sat', 'the'),
#  ('sat', 'cat'),
#  ('sat', 'on'),
#  ('sat', 'the'),
#  ('on', 'cat'),
#  ('on', 'sat'),
#  ('on', 'the'),
#  ('on', 'mat'),
#  ('the', 'sat'),
#  ('the', 'on'),
#  ('the', 'mat'),
#  ('mat', 'on'),
#  ('mat', 'the')]

# %%
# 3. Define Skip-Gram model
class SkipGram(nn.Module):
    def __init__(self,vocab_size,embed_dim):
        super().__init__()
        self.embeddings=nn.Embedding(vocab_size,embed_dim)
        self.output = nn.Linear(embed_dim,vocab_size)

    def forward(self,target_word):
        embed= self.embeddings(target_word)
        out = self.output(embed)
        return out

# %%
# 4. Training
vocab_size = len(vocab)
embed_dim = 10
model = SkipGram(vocab_size, embed_dim)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(100):
    total_loss = 0
    for target, context in pairs:
        target_idx = torch.tensor([word_to_ix[target]])
        context_idx = torch.tensor([word_to_ix[context]])

        # Forward
        logits = model(target_idx)
        loss = loss_fn(logits, context_idx)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    if epoch % 20 == 0:
        print(f"Epoch {epoch}, Loss: {total_loss:.4f}")
# Out:
# Epoch 0, Loss: 34.0285
# Epoch 20, Loss: 22.0915
# Epoch 40, Loss: 21.7102
# Epoch 60, Loss: 21.6059
# Epoch 80, Loss: 21.5587

# %%
# 5. Inspect embeddings
for word in vocab:
    print(word, model.embeddings.weight[word_to_ix[word]].detach())
# Out:
# on tensor([-0.7967, -0.5410,  0.0294,  2.1963, -1.1211, -0.7904,  0.1418, -0.7822,
#         -0.1583, -1.1755])
# sat tensor([ 2.7197,  0.3240,  0.3842, -0.4717,  0.1753, -0.8582,  1.2868,  1.5115,
#         -1.5871, -0.6233])
# cat tensor([ 0.4154,  2.1928, -0.1114,  0.5088, -1.0117,  1.4757,  1.3855, -0.7298,
#         -0.4603,  1.4506])
# the tensor([ 1.2610, -2.0358, -0.0401,  0.2600,  0.8264, -0.5929, -1.1368, -1.7898,
#         -0.3159,  2.3082])
# mat tensor([ 2.1416,  0.2538, -3.6436, -1.3006,  1.9636,  0.7277,  0.3724, -1.3204,
#         -0.4389, -1.2747])

# %%
! pip install gensim

# %%
# !pip install staticvectors

# %%
from staticvectors import StaticVectors

model = StaticVectors("neuml/glove-6B")
model.embeddings(["word"])
# Out:
# config.json:   0%|          | 0.00/149 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/480M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/7.69M [00:00<?, ?B/s]
# array([[-7.42449462e-02, -7.00803548e-02, -3.15346085e-02,
#         -2.16475874e-02,  7.50281801e-03, -3.66014689e-02,
#         -6.29846826e-02,  5.62374946e-03, -1.86802745e-02,
#         -2.33537942e-01, -3.30406912e-02,  3.27370614e-02,
#         -7.54853562e-02,  4.19857614e-02,  5.11965081e-02,
#         -4.32520472e-02, -4.23066467e-02, -3.76365781e-02,
#         -2.25257054e-02, -7.58924931e-02,  3.97154242e-02,
#          4.75149751e-02,  8.25103000e-03, -2.51324549e-02,
#         -5.59925139e-02,  7.57096261e-02, -2.74114218e-02,
#          2.41801552e-02,  4.31312844e-02,  6.90831989e-03,
#         -4.45045307e-02, -5.44726336e-03, -1.01250954e-01,
#         -4.40145768e-02, -4.05987166e-02,  1.36344612e-01,
#          2.39662323e-02,  2.25153547e-02,  3.04270405e-02,
#          9.58959833e-02,  3.42828222e-02, -4.96041700e-02,
#         -7.81507641e-02, -3.81368808e-02,  1.54562537e-02,
#         -6.12698533e-02, -1.05757127e-02,  1.58252701e-01,
#         -7.80817540e-03,  1.30491070e-02,  3.55284028e-02,
#          4.30985056e-02, -7.22385570e-02, -5.42759635e-02,
#          4.26327027e-02, -3.91133353e-02,  6.59761429e-02,
#         -9.13449526e-02,  3.95204797e-02, -5.20056225e-02,
#          1.31298453e-02,  6.54292628e-02,  3.88769843e-02,
#         -6.39714825e-04, -1.82265509e-02, -6.07505720e-03,
#         -3.72311585e-02, -2.80342121e-02,  1.19589634e-01,
#          2.98767071e-02, -2.49737389e-02,  6.42751232e-02,
#         -1.17095031e-01,  6.42440617e-02,  6.36920109e-02,
#          9.78747681e-02,  4.73631583e-02, -5.76193677e-03,
#          1.97654143e-02, -1.09088458e-01,  9.37101804e-03,
#          2.94195358e-02, -1.86578464e-02,  2.40956210e-02,
#         -1.20226234e-01, -3.93686630e-02,  2.48115733e-02,
#          2.41473783e-02,  3.07392981e-02,  3.54041904e-02,
#         -6.02916740e-02, -2.06987374e-02, -1.41956629e-02,
#         -4.75287735e-02,  3.25179622e-02,  2.74959579e-03,
#          8.28294549e-03, -8.16045795e-03,  5.99104092e-02,
#         -1.99638102e-02, -1.58131942e-02,  4.00621817e-03,
#          2.17528250e-02,  2.80428398e-02,  3.68464440e-02,
#          7.70932212e-02, -2.12490708e-02, -9.85010043e-02,
#         -2.20702570e-02, -6.55120760e-02,  1.27611728e-02,
#         -5.93134910e-02,  3.65911163e-02,  2.84758601e-02,
#         -2.11852398e-02,  1.22015243e-02, -1.64320169e-03,
#         -1.06726680e-03, -1.33572236e-01,  4.99267802e-02,
#         -9.55060944e-02, -4.16717790e-02,  3.05219255e-02,
#         -3.04063380e-01, -8.85053072e-03,  1.31907433e-01,
#         -1.24516767e-02, -1.41152695e-01, -3.14086713e-02,
#         -5.66291101e-02,  4.03140597e-02,  4.91090417e-02,
#          2.46649310e-02,  1.99586339e-02, -8.41112658e-02,
#          2.03830302e-02,  5.12879454e-02,  2.98784319e-02,
#          2.06245538e-02,  9.21385363e-03, -2.45665964e-02,
#          2.02087872e-02, -8.70199278e-02, -1.81609939e-03,
#          4.95765638e-03, -7.26594999e-02,  4.80480529e-02]], dtype=float32)

# %%
import numpy as np

v1 = model.embeddings(["cat"])[0]   # returns array inside a list
v2 = model.embeddings(["dog"])[0]

cosine = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
print(cosine)  # closer to 1 if similar
# Out:
# 0.6816748

# %%
v3 = model.embeddings(["cat"])[0]   # returns array inside a list
v4 = model.embeddings(["car"])[0]

cosine = np.dot(v3, v4) / (np.linalg.norm(v3) * np.linalg.norm(v4))
print(cosine)  # closer to 1 if similar
# Out:
# 0.14687802
